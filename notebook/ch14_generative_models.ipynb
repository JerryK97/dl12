# %% [markdown]
# <a href="https://colab.research.google.com/github/JerryK97/dl12/blob/main/notebook/ch14_generative_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ch14
# - auto encoder
# - gan

# %%
# -*- coding: utf-8 -*-

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

encoding_dim = 32  # 32픽셀로 압출
input_img = tf.keras.layers.Input(shape=(784,))
encoded = tf.keras.layers.Dense(encoding_dim, activation='relu')(input_img)
decoded = tf.keras.layers.Dense(784, activation='sigmoid')(encoded)
autoencoder = tf.keras.models.Model(input_img, decoded)

autoencoder.compile(optimizer='adam', loss=tf.keras.losses.MeanSquaredError())

mnist = tf.keras.datasets.mnist
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
print(x_train.shape)
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))


decoded_imgs = autoencoder.predict(x_test)
print(decoded_imgs.shape)

n = 10
plt.figure(figsize=(20, 6))
for i in range(1, n + 1):
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')

    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (60000, 784)
# Epoch 1/50
# 235/235 [==============================] - 3s 8ms/step - loss: 0.0690 - val_loss: 0.0404
# Epoch 2/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0347 - val_loss: 0.0292
# Epoch 3/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0261 - val_loss: 0.0228
# Epoch 4/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0212 - val_loss: 0.0191
# Epoch 5/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0183 - val_loss: 0.0168
# Epoch 6/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0162 - val_loss: 0.0150
# Epoch 7/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0146 - val_loss: 0.0136
# Epoch 8/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0134 - val_loss: 0.0125
# Epoch 9/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0124 - val_loss: 0.0117
# Epoch 10/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0118 - val_loss: 0.0112
# Epoch 11/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0113 - val_loss: 0.0108
# Epoch 12/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0110 - val_loss: 0.0105
# Epoch 13/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0108 - val_loss: 0.0103
# Epoch 14/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0106 - val_loss: 0.0102
# Epoch 15/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0105 - val_loss: 0.0101
# Epoch 16/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0104 - val_loss: 0.0100
# Epoch 17/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0103 - val_loss: 0.0100
# Epoch 18/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0103 - val_loss: 0.0099
# Epoch 19/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0103 - val_loss: 0.0099
# Epoch 20/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0102 - val_loss: 0.0099
# Epoch 21/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0102 - val_loss: 0.0099
# Epoch 22/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0102 - val_loss: 0.0098
# Epoch 23/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 24/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 25/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 26/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 27/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 28/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0101 - val_loss: 0.0097
# Epoch 29/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 30/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 31/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 32/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 33/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 34/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 35/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 36/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 37/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 38/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 39/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 40/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0099 - val_loss: 0.0097
# Epoch 41/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 42/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0099 - val_loss: 0.0097
# Epoch 43/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 44/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 45/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 46/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 47/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 48/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 49/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 50/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0099 - val_loss: 0.0096
# 313/313 [==============================] - 1s 2ms/step
# (10000, 784)

# %% [markdown]
# ## Denoising by auto encoder

# %%
# -*- coding: utf-8 -*-

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

encoding_dim = 32  
input_img = tf.keras.layers.Input(shape=(784,))
encoded = tf.keras.layers.Dense(encoding_dim, activation='relu')(input_img)
decoded = tf.keras.layers.Dense(784, activation='sigmoid')(encoded)
autoencoder = tf.keras.models.Model(input_img, decoded)  # (784,784)

mnist = tf.keras.datasets.mnist

(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
# Flattening: (28,28)=> (784,)
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

noise_factor = 0.55

original_train = x_train
original_test = x_test
noise_train = np.random.normal(0, 1, original_train.shape)
noise_test = np.random.normal(0, 1, original_test.shape)
noisy_train = original_train + noise_factor * noise_train
noisy_test = original_test + noise_factor * noise_test
print(noisy_train.shape)

autoencoder.compile(optimizer='adam', loss='mse')

autoencoder.fit(noisy_train, original_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(noisy_test, original_test))

denoised_images = autoencoder.predict(noisy_test)
print(denoised_images.shape)

n = 10
plt.figure(figsize=(20, 6))
for i in range(1, n + 1):
    ax = plt.subplot(3, n, i)
    plt.imshow(noisy_test[i].reshape(28, 28), cmap='gray')
    plt.gray()

    ax = plt.subplot(3, n, i + n)
    plt.imshow(denoised_images[i].reshape(28, 28), cmap='gray')
    plt.gray()

    ax = plt.subplot(3, n, i + 2*n)
    plt.imshow(original_test[i].reshape(28, 28), cmap='gray')
    plt.gray()
    
plt.show()
# Out:
# (60000, 784)
# Epoch 1/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0738 - val_loss: 0.0464
# Epoch 2/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0407 - val_loss: 0.0357
# Epoch 3/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0332 - val_loss: 0.0305
# Epoch 4/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0292 - val_loss: 0.0276
# Epoch 5/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0268 - val_loss: 0.0257
# Epoch 6/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0252 - val_loss: 0.0243
# Epoch 7/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0240 - val_loss: 0.0234
# Epoch 8/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0231 - val_loss: 0.0227
# Epoch 9/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0225 - val_loss: 0.0222
# Epoch 10/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0221 - val_loss: 0.0219
# Epoch 11/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0219 - val_loss: 0.0217
# Epoch 12/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0217 - val_loss: 0.0216
# Epoch 13/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0216 - val_loss: 0.0214
# Epoch 14/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0215 - val_loss: 0.0214
# Epoch 15/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0215 - val_loss: 0.0213
# Epoch 16/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0215 - val_loss: 0.0213
# Epoch 17/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0214 - val_loss: 0.0213
# Epoch 18/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0214 - val_loss: 0.0213
# Epoch 19/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0214 - val_loss: 0.0212
# Epoch 20/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0214 - val_loss: 0.0212
# Epoch 21/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0213 - val_loss: 0.0212
# Epoch 22/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0213 - val_loss: 0.0212
# Epoch 23/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0213 - val_loss: 0.0212
# Epoch 24/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0213 - val_loss: 0.0211
# Epoch 25/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0213 - val_loss: 0.0212
# Epoch 26/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0213 - val_loss: 0.0212
# Epoch 27/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0212 - val_loss: 0.0211
# Epoch 28/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0212 - val_loss: 0.0211
# Epoch 29/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0212 - val_loss: 0.0211
# Epoch 30/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0212 - val_loss: 0.0211
# Epoch 31/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0212 - val_loss: 0.0211
# Epoch 32/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0212 - val_loss: 0.0211
# Epoch 33/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0212 - val_loss: 0.0211
# Epoch 34/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0212 - val_loss: 0.0211
# Epoch 35/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0212 - val_loss: 0.0211
# Epoch 36/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0212 - val_loss: 0.0210
# Epoch 37/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0211 - val_loss: 0.0211
# Epoch 38/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0211 - val_loss: 0.0211
# Epoch 39/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0211 - val_loss: 0.0210
# Epoch 40/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0211 - val_loss: 0.0210
# Epoch 41/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0211 - val_loss: 0.0210
# Epoch 42/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0211 - val_loss: 0.0210
# Epoch 43/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0211 - val_loss: 0.0210
# Epoch 44/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0211 - val_loss: 0.0210
# Epoch 45/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0211 - val_loss: 0.0210
# Epoch 46/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0211 - val_loss: 0.0210
# Epoch 47/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0211 - val_loss: 0.0210
# Epoch 48/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0211 - val_loss: 0.0210
# Epoch 49/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0211 - val_loss: 0.0210
# Epoch 50/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0211 - val_loss: 0.0210
# 313/313 [==============================] - 1s 1ms/step
# (10000, 784)

# %% [markdown]
# ## generative image
# - VAE (variation auto encoder)
